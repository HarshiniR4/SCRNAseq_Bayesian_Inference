# %% [markdown]
# ## Extracting files

# %%
# Replace 'GSE98969_RAW.tar' with the path to your file
file_path = 'GSE98969_RAW.tar'

# %%
import tarfile


# Open the tar file
with tarfile.open(file_path, 'r') as tar:
    # Extract all files to the current directory or specify a path
    tar.extractall(path= file_path +'_extracted_files')

print("Extraction completed.")
# Out:
# Extraction completed.

# %%
import os
import gzip
import shutil
import pandas as pd

# %%
# !pip uninstall scanpy -y
# !pip install -q scanpy
# !pip install -q python-igraph
# !pip install -q louvain

# %%
import pandas as pd
import os 
# Load metadata file (e.g., downloaded as 'sra_metadata.csv')
file_name = file_path.split('_')[0]
metadata_path = file_name + "_SraRunTable.csv"
metadata = pd.read_csv(metadata_path)  # Adjust delimiter if necessary, e.g., `sep="\t"` for TSV

# Preview the metadata
print(metadata.head())
# Out:
#           Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 0  SRR5570818    RNA-Seq          66  1787012832  PRJNA387079  SAMN07134144
# 1  SRR5570819    RNA-Seq          66  1754542416  PRJNA387079  SAMN07134143
# 2  SRR5570820    RNA-Seq          66  2025254748  PRJNA387079  SAMN07134095
# 3  SRR5570821    RNA-Seq          66  1903373934  PRJNA387079  SAMN07134112
# 4  SRR5570822    RNA-Seq          66  1897330314  PRJNA387079  SAMN07134111
#
#         Bytes Center Name Consent DATASTORE filetype  ...  Platform  \
# 0  2837501765         GEO  public   fastq,run.zq,sra  ...  ILLUMINA
# 1  2787916655         GEO  public   fastq,run.zq,sra  ...  ILLUMINA
# 2  3215106227         GEO  public   fastq,run.zq,sra  ...  ILLUMINA
# 3  3023441918         GEO  public   fastq,run.zq,sra  ...  ILLUMINA
# 4  3016457388         GEO  public   fastq,run.zq,sra  ...  ILLUMINA
#
#             ReleaseDate           create_date version Sample Name  \
# 0  2017-06-12T00:00:00Z  2017-05-16T17:45:00Z       2  GSM2629342
# 1  2017-06-12T00:00:00Z  2017-05-16T17:52:00Z       2  GSM2629343
# 2  2017-06-12T00:00:00Z  2019-10-04T18:33:00Z       4  GSM2629344
# 3  2017-06-12T00:00:00Z  2017-05-16T17:43:00Z       2  GSM2629345
# 4  2017-06-12T00:00:00Z  2017-05-16T17:50:00Z       2  GSM2629346
#
#   selection_marker  source_name  SRA Study   strain            treatment
# 0            CD45+  Whole brain  SRP107339  C57BL/6  Alzheimer's disease
# 1            CD45+  Whole brain  SRP107339  C57BL/6  Alzheimer's disease
# 2            CD45+  Whole brain  SRP107339    5XFAD  Alzheimer's disease
# 3            CD45+  Whole brain  SRP107339  C57BL/6  Alzheimer's disease
# 4            CD45+  Whole brain  SRP107339  C57BL/6  Alzheimer's disease
#
# [5 rows x 31 columns]

# %%
metadata = metadata.drop(['chip_antibody', 'enrichment', 'tissue'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 metadata = metadata.drop(['chip_antibody', 'enrichment', 'tissue'], axis=1)
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['chip_antibody', 'enrichment', 'tissue'] not found in axis"

# %%
# Prepare metadata for matching
metadata_filtered = metadata.set_index("Sample Name")

# %%
import os
import pandas as pd
import concurrent.futures
import gzip

# Define the directory containing the extracted .gz files
gz_directory = file_path + '_extracted_files'

# List all .gz files in the directory
files = [f for f in os.listdir(gz_directory) if f.endswith('.gz')]

def process_file(file_name):
    """Reads the extracted .txt file corresponding to the .gz file and returns metadata and DataFrame."""
    try:
        print(f"Processing: {file_name}")
        gz_path = os.path.join(gz_directory, file_name)
        txt_file = os.path.splitext(file_name)[0]
        txt_path = os.path.join(gz_directory, txt_file)

        # Decompress the .gz file to .txt
        with gzip.open(gz_path, 'rb') as f_in:
            with open(txt_path, 'wb') as f_out:
                f_out.write(f_in.read())

        # Read the .txt file into a DataFrame
        data = pd.read_csv(txt_path, sep='\t', index_col=0, on_bad_lines='skip')

        # Extract key for metadata dictionary
        key = os.path.splitext(txt_file)[0].split('_')[0]
        return key, data
    
    except Exception as e:
        print(f"❌ Failed to process {file_name}: {e}")
        return None  # Skip this file

# Dictionaries to store metadata and list to collect DataFrames
metadata_dict = {}
all_data = []

# Process the files in parallel using 3 workers
with concurrent.futures.ProcessPoolExecutor(max_workers=3) as executor:
    results = filter(None, executor.map(process_file, files))  # Filter out None results

    # Process the results
    for key, data in results:
        metadata_dict[key] = data.columns.tolist()
        all_data.append(data)

# Combine all the DataFrames along the column axis
combined_data = pd.concat(all_data, axis=1)
print("✅ All valid .txt files have been read and combined.")
# Out:
# Processing: GSM2629436_AB2431.txt.gz
# Processing: GSM2629417_AB2333.txt.gz
# Processing: GSM2629361_AB1556.txt.gz
# Processing: GSM2629437_AB2432.txt.gz
# Processing: GSM2629359_AB1554.txt.gz
# Processing: GSM2629358_AB1553.txt.gz
# Processing: GSM2629387_AB1730.txt.gz
# Processing: GSM2629415_AB2331.txt.gz
# Processing: GSM2629435_AB2430.txt.gz
# Processing: GSM2629370_AB1713.txt.gz
# Processing: GSM2629430_AB2425.txt.gz
# Processing: GSM2629388_AB1731.txt.gz
# Processing: GSM2629422_AB2338.txt.gz
# ❌ Failed to process GSM2629430_AB2425.txt.gz: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
# Processing: GSM2629442_AB2437.txt.gz
# Processing: GSM2629355_AB1550.txt.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 45
#      44 # Process the results
# ---> 45 for key, data in results:
#      46     metadata_dict[key] = data.columns.tolist()
#
# File /usr/lib64/python3.9/concurrent/futures/process.py:562, in _chain_from_iterable_of_lists(iterable)
#     557 """
#     558 Specialized implementation of itertools.chain.from_iterable.
#     559 Each item in *iterable* should be a list.  This function is
#     560 careful not to keep references to yielded objects.
#     561 """
# --> 562 for element in iterable:
#     563     element.reverse()
#
# File /usr/lib64/python3.9/concurrent/futures/_base.py:609, in Executor.map.<locals>.result_iterator()
#     608 if timeout is None:
# --> 609     yield fs.pop().result()
#     610 else:
#
# File /usr/lib64/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib64/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     311 if timeout is None:
# --> 312     waiter.acquire()
#     313     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 47
#      45     for key, data in results:
#      46         metadata_dict[key] = data.columns.tolist()
# ---> 47         all_data.append(data)
#      49 # Combine all the DataFrames along the column axis
#      50 combined_data = pd.concat(all_data, axis=1)
#
# File /usr/lib64/python3.9/concurrent/futures/_base.py:637, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     636 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 637     self.shutdown(wait=True)
#     638     return False
#
# File /usr/lib64/python3.9/concurrent/futures/process.py:767, in ProcessPoolExecutor.shutdown(self, wait, cancel_futures)
#     764         self._executor_manager_thread_wakeup.wakeup()
#     766 if self._executor_manager_thread is not None and wait:
# --> 767     self._executor_manager_thread.join()
#     768 # To reduce the risk of opening too many files, remove references to
#     769 # objects that use file descriptors.
#     770 self._executor_manager_thread = None
#
# File /usr/lib64/python3.9/threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib64/python3.9/threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:

# %%
# Create a DataFrame to store metadata information
metadata_to_add = pd.DataFrame(index=combined_data.columns)

# %%
combined_data.shape
# Out:
# (23429, 1923)

# %%
# Ensure metadata index is string
metadata_filtered.index = metadata_filtered.index.astype(str)

# Build the reverse mapping: for every column (cell barcode), map it to its file key
column_to_file = {
    col: file_name
    for file_name, cols in metadata_dict.items()
    for col in cols
}

# Create a DataFrame mapping each cell barcode in combined_data to its file key
mapping_df = pd.DataFrame({
    'col_name': combined_data.columns,
    'file_key': combined_data.columns.map(column_to_file)
})

# Reset metadata_filtered index to a column. If the index name isn't set, it defaults to "index".
metadata_df = metadata_filtered.reset_index()
current_key_name = metadata_filtered.index.name if metadata_filtered.index.name is not None else 'index'
metadata_df.rename(columns={current_key_name: 'file_key'}, inplace=True)

# Merge the mapping with the metadata
merged_df = mapping_df.merge(metadata_df, on='file_key', how='left')

# In case there are duplicates (multiple metadata rows per cell), take the first occurrence per cell barcode
merged_df = merged_df.groupby("col_name", as_index=False).first()

# Now set the index to the cell barcodes
metadata_to_add = merged_df.set_index("col_name").drop(columns=["file_key"])

# %%
metadata_to_add.shape
# Out:
# (37248, 30)

# %%
import scanpy as sc

# %%
# Remove duplicated columns (cells) from combined_data before creating AnnData
combined_data = combined_data.loc[:, ~combined_data.columns.duplicated(keep='first')]

# %%
# Create AnnData object
adata = sc.AnnData(combined_data.T.values)  # Transpose to match AnnData cell-by-gene format

# %%
# Set obs_names (sample IDs) and var_names (gene IDs)
adata.obs_names = combined_data.columns
adata.var_names = combined_data.index

# %%
print("adata.obs index duplicated:", adata.obs.index.duplicated().sum())
print("metadata_to_add index duplicated:", metadata_to_add.index.duplicated().sum())
# Out:
# adata.obs index duplicated: 0
# metadata_to_add index duplicated: 0

# %%
# Now this should work
adata.obs = pd.concat([adata.obs, metadata_to_add], axis=1)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 37248 × 34016
#     obs: 'Run', 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject', 'BioSample', 'Bytes', 'Center Name', 'Consent', 'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region', 'Experiment', 'GEO_Accession (exp)', 'Instrument', 'LibraryLayout', 'LibrarySelection', 'LibrarySource', 'mouse_age', 'Organ', 'Organism', 'Platform', 'ReleaseDate', 'create_date', 'version', 'selection_marker', 'source_name', 'SRA Study', 'strain', 'treatment'

# %%
adata.obs
# Out:
#                 Run Assay Type  AvgSpotLen       Bases   BioProject  \
# W660497  SRR5570912    RNA-Seq          66  1727997546  PRJNA387079
# W660498  SRR5570912    RNA-Seq          66  1727997546  PRJNA387079
# W660499  SRR5570912    RNA-Seq          66  1727997546  PRJNA387079
# W660500  SRR5570912    RNA-Seq          66  1727997546  PRJNA387079
# W660501  SRR5570912    RNA-Seq          66  1727997546  PRJNA387079
# ...             ...        ...         ...         ...          ...
# W625932  SRR5570900    RNA-Seq          66  1311093300  PRJNA387079
# W625933  SRR5570900    RNA-Seq          66  1311093300  PRJNA387079
# W625934  SRR5570900    RNA-Seq          66  1311093300  PRJNA387079
# W625935  SRR5570900    RNA-Seq          66  1311093300  PRJNA387079
# W625936  SRR5570900    RNA-Seq          66  1311093300  PRJNA387079
#
#             BioSample       Bytes Center Name Consent DATASTORE filetype  ...  \
# W660497  SAMN07134176  2790797468         GEO  public   fastq,run.zq,sra  ...
# W660498  SAMN07134176  2790797468         GEO  public   fastq,run.zq,sra  ...
# W660499  SAMN07134176  2790797468         GEO  public   fastq,run.zq,sra  ...
# W660500  SAMN07134176  2790797468         GEO  public   fastq,run.zq,sra  ...
# W660501  SAMN07134176  2790797468         GEO  public   fastq,run.zq,sra  ...
# ...               ...         ...         ...     ...                ...  ...
# W625932  SAMN07134158  2140769744         GEO  public   fastq,run.zq,sra  ...
# W625933  SAMN07134158  2140769744         GEO  public   fastq,run.zq,sra  ...
# W625934  SAMN07134158  2140769744         GEO  public   fastq,run.zq,sra  ...
# W625935  SAMN07134158  2140769744         GEO  public   fastq,run.zq,sra  ...
# W625936  SAMN07134158  2140769744         GEO  public   fastq,run.zq,sra  ...
#
#              Organism  Platform           ReleaseDate           create_date  \
# W660497  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:43:00Z
# W660498  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:43:00Z
# W660499  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:43:00Z
# W660500  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:43:00Z
# W660501  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:43:00Z
# ...               ...       ...                   ...                   ...
# W625932  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:23:00Z
# W625933  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:23:00Z
# W625934  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:23:00Z
# W625935  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:23:00Z
# W625936  Mus musculus  ILLUMINA  2017-06-12T00:00:00Z  2017-05-16T17:23:00Z
#
#         version selection_marker  source_name  SRA Study   strain  \
# W660497       2            CD45+       Cortex  SRP107339    5XFAD
# W660498       2            CD45+       Cortex  SRP107339    5XFAD
# W660499       2            CD45+       Cortex  SRP107339    5XFAD
# W660500       2            CD45+       Cortex  SRP107339    5XFAD
# W660501       2            CD45+       Cortex  SRP107339    5XFAD
# ...         ...              ...          ...        ...      ...
# W625932       2            CD45+  Whole brain  SRP107339  C57BL/6
# W625933       2            CD45+  Whole brain  SRP107339  C57BL/6
# W625934       2            CD45+  Whole brain  SRP107339  C57BL/6
# W625935       2            CD45+  Whole brain  SRP107339  C57BL/6
# W625936       2            CD45+  Whole brain  SRP107339  C57BL/6
#
#                    treatment
# W660497  Alzheimer's disease
# W660498  Alzheimer's disease
# W660499  Alzheimer's disease
# W660500  Alzheimer's disease
# W660501  Alzheimer's disease
# ...                      ...
# W625932  Alzheimer's disease
# W625933  Alzheimer's disease
# W625934  Alzheimer's disease
# W625935  Alzheimer's disease
# W625936  Alzheimer's disease
#
# [37248 rows x 30 columns]

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [0610005C13Rik, 0610007C21Rik, 0610007L01Rik, 0610007P08Rik, 0610007P14Rik, 0610007P22Rik, 0610008F07Rik, 0610009B14Rik, 0610009B22Rik, 0610009D07Rik, 0610009E02Rik, 0610009L18Rik, 0610009O20Rik, 0610010F05Rik, 0610010K14Rik, 0610010O12Rik, 0610011F06Rik, 0610011L14Rik, 0610012D04Rik, 0610012G03Rik, 0610012H03Rik, 0610025J13Rik, 0610030E20Rik, 0610031J06Rik, 0610037L13Rik, 0610037P05Rik, 0610038L08Rik, 0610038P03Rik, 0610039K10Rik, 0610040B09Rik, 0610040B10Rik, 0610040F04Rik, 0610040J01Rik, 0610043K17Rik, 0910001L09Rik, 1010001B22Rik, 1010001N08Rik, 1100001G20Rik, 1110001A16Rik, 1110001J03Rik, 1110002B05Rik, 1110002E22Rik, 1110002J07Rik, 1110002L01Rik, 1110002N22Rik, 1110003E01Rik, 1110003O08Rik, 1110004E09Rik, 1110004F10Rik, 1110005A03Rik, 1110006G14Rik, 1110007C09Rik, 1110008E08Rik, 1110008F13Rik, 1110008J03Rik, 1110008L16Rik, 1110008P14Rik, 1110012D08Rik, 1110012J17Rik, 1110012L19Rik, 1110014N23Rik, 1110017D15Rik, 1110017F19Rik, 1110018G07Rik, 1110018J18Rik, 1110018N20Rik, 1110019D14Rik, 1110020A21Rik, 1110020G09Rik, 1110021J02Rik, 1110021L09Rik, 1110025L11Rik, 1110028C15Rik, 1110028F11Rik, 1110031I02Rik, 1110032A03Rik, 1110032A04Rik, 1110032F04Rik, 1110034A24Rik, 1110034B05Rik, 1110034G24Rik, 1110035H17Rik, 1110035M17Rik, 1110036E04Rik, 1110037F02Rik, 1110038B12Rik, 1110038D17Rik, 1110038F14Rik, 1110046J04Rik, 1110049F12Rik, 1110050K14Rik, 1110051M20Rik, 1110054M08Rik, 1110054O05Rik, 1110057K04Rik, 1110057P08Rik, 1110058L19Rik, 1110059E24Rik, 1110059G10Rik, 1110059M19Rik, ...]
#
# [34016 rows x 0 columns]

# %%
# Save the AnnData object
adata.write(file_name +"_GSM_preprocessed_with_metadata.h5ad")

print("Preprocessing complete. AnnData saved with metadata.")
# Out:
# Preprocessing complete. AnnData saved with metadata.

# %% [markdown]
# ## For csv.gz file

# %%
import scanpy as sc
import pandas as pd
# Scanpy can directly read a CSV file (assuming the file is formatted as a proper matrix)
combined_data = pd.read_csv('GSE123025_Single_myeloid_1922_cells_processed_data.csv.gz', index_col=0)

# %%
metadata = pd.read_csv('GSE123025_SraRunTable.csv', index_col=0)

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1922 entries, SRR8250775 to SRR8252696
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Assay Type            1922 non-null   object
#  1   AvgSpotLen            1922 non-null   int64
#  2   Bases                 1922 non-null   int64
#  3   BioProject            1922 non-null   object
#  4   BioSample             1922 non-null   object
#  5   Bytes                 1922 non-null   int64
#  6   Center Name           1922 non-null   object
#  7   Consent               1922 non-null   object
#  8   DATASTORE filetype    1922 non-null   object
#  9   DATASTORE provider    1922 non-null   object
#  10  DATASTORE region      1922 non-null   object
#  11  Experiment            1922 non-null   object
#  12  GEO_Accession (exp)   1922 non-null   object
#  13  Instrument            1922 non-null   object
#  14  LibraryLayout         1922 non-null   object
#  15  LibrarySelection      1922 non-null   object
#  16  LibrarySource         1922 non-null   object
#  17  Organism              1922 non-null   object
#  18  Platform              1922 non-null   object
#  19  ReleaseDate           1922 non-null   object
#  20  Sample Name           1922 non-null   object
#  21  SRA Study             1922 non-null   object
#  22  create_date           1915 non-null   object
#  23  version               1915 non-null   float64
#  24  AGE                   1891 non-null   object
#  25  detected_genes        1891 non-null   float64
#  26  gate                  1891 non-null   object
#  27  genotype              1891 non-null   object
#  28  plate_id              1891 non-null   float64
#  29  pooled_library_names  1891 non-null   object
#  30  qc_all_3_criteria     1891 non-null   object
#  31  qc_detected_genes     1891 non-null   object
#  32  qc_ercc_correlation   1891 non-null   object
#  33  qc_total_counts       1891 non-null   object
#  34  source_name           1891 non-null   object
#  35  strain                1891 non-null   object
#  36  tissue                1891 non-null   object
#  37  total_counts          1891 non-null   float64
#  38  well_id               1891 non-null   object
# dtypes: float64(4), int64(3), object(32)
# memory usage: 600.6+ KB

# %%
# Remove any newline characters in each column
metadata["well_id"] = (
    metadata["well_id"]
    .astype(str)
    .str.replace(r"\n", "", regex=True)
    .str.strip()
)
metadata["plate_id"] = (
    metadata["plate_id"]
    .astype(str)
    .str.replace(r"\n", "", regex=True)
    .str.strip()
)

# Now concatenate them with a dot
metadata["Name"] = (
    metadata["well_id"] + "." + metadata["plate_id"]
)

# %%
# Prepare metadata for matching
metadata_filtered = metadata.set_index('Name')

# %%
metadata_filtered
# Out:
#                  Assay Type  AvgSpotLen      Bases   BioProject     BioSample  \
# Name
# C9.1001200107.0     RNA-Seq         150  168482850  PRJNA507279  SAMN10488168
# B10.1001200106.0    RNA-Seq         150  245394750  PRJNA507279  SAMN10488167
# A8.1001200106.0     RNA-Seq         150  214195950  PRJNA507279  SAMN10488166
# D6.1001200107.0     RNA-Seq         150  226942050  PRJNA507279  SAMN10488165
# B12.1001200106.0    RNA-Seq         150  229187700  PRJNA507279  SAMN10488164
# ...                     ...         ...        ...          ...           ...
# H8.1001200140.0     RNA-Seq         150  174234150  PRJNA507279  SAMN10490715
# H8.1001200141.0     RNA-Seq         150  228931950  PRJNA507279  SAMN10490714
# H9.1001200136.0     RNA-Seq         150  231320100  PRJNA507279  SAMN10490713
# H9.1001200140.0     RNA-Seq         150  105890250  PRJNA507279  SAMN10490712
# H9.1001200141.0     RNA-Seq         150  232553400  PRJNA507279  SAMN10490711
#
#                      Bytes Center Name Consent DATASTORE filetype  \
# Name
# C9.1001200107.0   60931001         GEO  public   fastq,run.zq,sra
# B10.1001200106.0  89790040         GEO  public   fastq,run.zq,sra
# A8.1001200106.0   78644825         GEO  public   fastq,run.zq,sra
# D6.1001200107.0   82714715         GEO  public   fastq,run.zq,sra
# B12.1001200106.0  82956576         GEO  public   fastq,run.zq,sra
# ...                    ...         ...     ...                ...
# H8.1001200140.0   69638065         GEO  public   fastq,run.zq,sra
# H8.1001200141.0   91144992         GEO  public   fastq,run.zq,sra
# H9.1001200136.0   92742851         GEO  public   fastq,run.zq,sra
# H9.1001200140.0   41710381         GEO  public   fastq,run.zq,sra
# H9.1001200141.0   92568030         GEO  public   fastq,run.zq,sra
#
#                  DATASTORE provider  ... pooled_library_names  \
# Name                                 ...
# C9.1001200107.0          gs,ncbi,s3  ...           MG_YS_lib2
# B10.1001200106.0         gs,ncbi,s3  ...           MG_YS_lib2
# A8.1001200106.0          gs,ncbi,s3  ...           MG_YS_lib2
# D6.1001200107.0          gs,ncbi,s3  ...           MG_YS_lib2
# B12.1001200106.0         gs,ncbi,s3  ...           MG_YS_lib2
# ...                             ...  ...                  ...
# H8.1001200140.0          gs,ncbi,s3  ...      N496_MG_lib5_CP
# H8.1001200141.0          gs,ncbi,s3  ...      N496_MG_lib5_CP
# H9.1001200136.0          gs,ncbi,s3  ...      N496_MG_lib5_CP
# H9.1001200140.0          gs,ncbi,s3  ...      N496_MG_lib5_CP
# H9.1001200141.0          gs,ncbi,s3  ...      N496_MG_lib5_CP
#
#                  qc_all_3_criteria qc_detected_genes qc_ercc_correlation  \
# Name
# C9.1001200107.0                  Y                 Y                   Y
# B10.1001200106.0                 Y                 Y                   Y
# A8.1001200106.0                  Y                 Y                   Y
# D6.1001200107.0                  Y                 Y                   Y
# B12.1001200106.0                 Y                 Y                   Y
# ...                            ...               ...                 ...
# H8.1001200140.0                  Y                 Y                   Y
# H8.1001200141.0                  Y                 Y                   Y
# H9.1001200136.0                  Y                 Y                   Y
# H9.1001200140.0                  Y                 Y                   Y
# H9.1001200141.0                  Y                 Y                   Y
#
#                  qc_total_counts         source_name   strain tissue  \
# Name
# C9.1001200107.0                Y  Brain myeloid cell  C57BL6N    HIP
# B10.1001200106.0               Y  Brain myeloid cell  C57BL6N     OB
# A8.1001200106.0                Y  Brain myeloid cell  C57BL6N     OB
# D6.1001200107.0                Y  Brain myeloid cell  C57BL6N    HIP
# B12.1001200106.0               Y  Brain myeloid cell  C57BL6N     OB
# ...                          ...                 ...      ...    ...
# H8.1001200140.0                Y  Brain myeloid cell  C57BL6N     CP
# H8.1001200141.0                Y  Brain myeloid cell  C57BL6N     CP
# H9.1001200136.0                Y  Brain myeloid cell  C57BL6N     CP
# H9.1001200140.0                Y  Brain myeloid cell  C57BL6N     CP
# H9.1001200141.0                Y  Brain myeloid cell  C57BL6N     CP
#
#                  total_counts well_id
# Name
# C9.1001200107.0      484029.0      C9
# B10.1001200106.0     810207.0     B10
# A8.1001200106.0      714754.0      A8
# D6.1001200107.0      716677.0      D6
# B12.1001200106.0     683013.0     B12
# ...                       ...     ...
# H8.1001200140.0      580160.0      H8
# H8.1001200141.0      748144.0      H8
# H9.1001200136.0      578801.0      H9
# H9.1001200140.0      307216.0      H9
# H9.1001200141.0      795783.0      H9
#
# [1922 rows x 39 columns]

# %%
new_columns = []
for col in combined_data.columns:
    new_key = col + ".0"
    if new_key in metadata_filtered.index:
        # Get the new value from metadata
        new_value = metadata_filtered.loc[new_key, "Sample Name"]
        new_columns.append(new_value)
    else:
        new_columns.append(col)

# Replace the columns in combined_data with the new column names
combined_data.columns = new_columns

# %%
# Create a DataFrame to store metadata information
metadata_to_add = pd.DataFrame(index=combined_data.columns)

# %%
metadata_to_add
# Out:
# Empty DataFrame
# Columns: []
# Index: [GSM3491382, GSM3491383, GSM3491384, GSM3491385, GSM3491386, GSM3491387, GSM3491388, GSM3491389, GSM3491390, GSM3491391, GSM3491392, GSM3491393, GSM3491394, GSM3491395, GSM3491396, GSM3491397, GSM3491398, GSM3491399, GSM3491400, GSM3491401, GSM3491402, GSM3491403, GSM3491404, GSM3491405, GSM3491406, GSM3491407, GSM3491408, GSM3491409, GSM3491410, GSM3491411, GSM3491412, GSM3491413, GSM3491414, GSM3491415, GSM3491416, GSM3491417, GSM3491418, GSM3491419, GSM3491420, GSM3491421, GSM3491422, GSM3491423, GSM3491424, GSM3491425, GSM3491426, GSM3491427, GSM3491428, GSM3491429, GSM3491430, GSM3491431, GSM3491432, GSM3491433, GSM3491434, GSM3491435, GSM3491436, GSM3491437, GSM3491438, GSM3491439, GSM3491440, GSM3491441, GSM3491442, GSM3491443, GSM3491444, GSM3491445, GSM3491446, GSM3491447, GSM3491448, GSM3491449, GSM3491450, GSM3491451, GSM3491452, GSM3491453, GSM3491454, GSM3491455, GSM3491456, GSM3491457, GSM3491458, GSM3491459, GSM3491460, GSM3491461, GSM3491462, GSM3491463, GSM3491464, GSM3491465, GSM3491466, GSM3491467, GSM3491468, GSM3491469, GSM3491470, GSM3491471, GSM3491472, GSM3491473, GSM3491474, GSM3491475, GSM3491476, GSM3491477, GSM3491478, GSM3491479, GSM3491480, GSM3491481, ...]
#
# [1922 rows x 0 columns]

# %%
# Prepare metadata for matching
metadata_filtered = metadata.set_index('Sample Name')

# %%
metadata_dict = combined_data.columns.tolist()

# %%
# Iterate through obs_names and match with metadata_dict
for col_name in combined_data.columns:
    print(f"col_name : {col_name}")
    # Find the corresponding key in metadata_dict
    matched_key = None
    for columns in metadata_dict:
        if col_name in columns:
            matched_key = columns
            break
    
    # If a match is found, add metadata row
    if matched_key is not None:
        print(f"matched_key: {matched_key}")
        metadata_row = metadata_filtered.loc[matched_key]
        for column in metadata_row.index:
            metadata_to_add.at[col_name, column] = metadata_row[column]
# Out:
# col_name : GSM3491382
# matched_key: GSM3491382
# col_name : GSM3491383
# matched_key: GSM3491383
# col_name : GSM3491384
# matched_key: GSM3491384
# col_name : GSM3491385
# matched_key: GSM3491385
# col_name : GSM3491386
# matched_key: GSM3491386
# col_name : GSM3491387
# matched_key: GSM3491387
# col_name : GSM3491388
# matched_key: GSM3491388
# col_name : GSM3491389
# matched_key: GSM3491389
# col_name : GSM3491390
# matched_key: GSM3491390
# col_name : GSM3491391
# matched_key: GSM3491391
# col_name : GSM3491392
# matched_key: GSM3491392
# col_name : GSM3491393
# matched_key: GSM3491393
# col_name : GSM3491394
# matched_key: GSM3491394
# col_name : GSM3491395
# matched_key: GSM3491395
# col_name : GSM3491396
# matched_key: GSM3491396
# col_name : GSM3491397
# matched_key: GSM3491397
# col_name : GSM3491398
# matched_key: GSM3491398
# col_name : GSM3491399
# matched_key: GSM3491399
# col_name : GSM3491400
# matched_key: GSM3491400
# col_name : GSM3491401
# matched_key: GSM3491401
# col_name : GSM3491402
# matched_key: GSM3491402
# col_name : GSM3491403
# matched_key: GSM3491403
# col_name : GSM3491404
# matched_key: GSM3491404
# col_name : GSM3491405
# matched_key: GSM3491405
# col_name : GSM3491406
# matched_key: GSM3491406
# col_name : GSM3491407
# matched_key: GSM3491407
# col_name : GSM3491408
# matched_key: GSM3491408
# col_name : GSM3491409
# matched_key: GSM3491409
# col_name : GSM3491410
# matched_key: GSM3491410
# col_name : GSM3491411
# matched_key: GSM3491411
# col_name : GSM3491412
# matched_key: GSM3491412
# col_name : GSM3491413
# matched_key: GSM3491413
# col_name : GSM3491414
# matched_key: GSM3491414
# col_name : GSM3491415
# matched_key: GSM3491415
# col_name : GSM3491416
# matched_key: GSM3491416
# col_name : GSM3491417
# matched_key: GSM3491417
# col_name : GSM3491418
# matched_key: GSM3491418
# col_name : GSM3491419
# matched_key: GSM3491419
# col_name : GSM3491420
# matched_key: GSM3491420
# col_name : GSM3491421
# matched_key: GSM3491421
# col_name : GSM3491422
# matched_key: GSM3491422
# col_name : GSM3491423
# matched_key: GSM3491423
# col_name : GSM3491424
# matched_key: GSM3491424
# col_name : GSM3491425
# matched_key: GSM3491425
# col_name : GSM3491426
# matched_key: GSM3491426
# col_name : GSM3491427
# matched_key: GSM3491427
# col_name : GSM3491428
# matched_key: GSM3491428
# col_name : GSM3491429
# matched_key: GSM3491429
# col_name : GSM3491430
# matched_key: GSM3491430
# col_name : GSM3491431
# matched_key: GSM3491431
# col_name : GSM3491432
# matched_key: GSM3491432
# col_name : GSM3491433
# matched_key: GSM3491433
# col_name : GSM3491434
# matched_key: GSM3491434
# col_name : GSM3491435
# matched_key: GSM3491435
# col_name : GSM3491436
# matched_key: GSM3491436
# col_name : GSM3491437
# matched_key: GSM3491437
# col_name : GSM3491438
# matched_key: GSM3491438
# col_name : GSM3491439
# matched_key: GSM3491439
# col_name : GSM3491440
# matched_key: GSM3491440
# col_name : GSM3491441
# matched_key: GSM3491441
# col_name : GSM3491442
# matched_key: GSM3491442
# col_name : GSM3491443
# matched_key: GSM3491443
# col_name : GSM3491444
# matched_key: GSM3491444
# col_name : GSM3491445
# matched_key: GSM3491445
# col_name : GSM3491446
# matched_key: GSM3491446
# col_name : GSM3491447
# matched_key: GSM3491447
# col_name : GSM3491448
# matched_key: GSM3491448
# col_name : GSM3491449
# matched_key: GSM3491449
# col_name : GSM3491450
# matched_key: GSM3491450
# col_name : GSM3491451
# matched_key: GSM3491451
# col_name : GSM3491452
# matched_key: GSM3491452
# col_name : GSM3491453
# matched_key: GSM3491453
# col_name : GSM3491454
# matched_key: GSM3491454
# col_name : GSM3491455
# matched_key: GSM3491455
# col_name : GSM3491456
# matched_key: GSM3491456
# col_name : GSM3491457
# matched_key: GSM3491457
# col_name : GSM3491458
# matched_key: GSM3491458
# col_name : GSM3491459
# matched_key: GSM3491459
# col_name : GSM3491460
# matched_key: GSM3491460
# col_name : GSM3491461
# matched_key: GSM3491461
# col_name : GSM3491462
# matched_key: GSM3491462
# col_name : GSM3491463
# matched_key: GSM3491463
# col_name : GSM3491464
# matched_key: GSM3491464
# col_name : GSM3491465
# matched_key: GSM3491465
# col_name : GSM3491466
# matched_key: GSM3491466
# col_name : GSM3491467
# matched_key: GSM3491467
# col_name : GSM3491468
# matched_key: GSM3491468
# col_name : GSM3491469
# matched_key: GSM3491469
# col_name : GSM3491470
# matched_key: GSM3491470
# col_name : GSM3491471
# matched_key: GSM3491471
# col_name : GSM3491472
# matched_key: GSM3491472
# col_name : GSM3491473
# matched_key: GSM3491473
# col_name : GSM3491474
# matched_key: GSM3491474
# col_name : GSM3491475
# matched_key: GSM3491475
# col_name : GSM3491476
# matched_key: GSM3491476
# col_name : GSM3491477
# matched_key: GSM3491477
# col_name : GSM3491478
# matched_key: GSM3491478
# col_name : GSM3491479
# matched_key: GSM3491479
# col_name : GSM3491480
# matched_key: GSM3491480
# col_name : GSM3491481
# matched_key: GSM3491481
# col_name : GSM3491482
# matched_key: GSM3491482
# col_name : GSM3491483
# matched_key: GSM3491483
# col_name : GSM3491484
# matched_key: GSM3491484
# col_name : GSM3491485
# matched_key: GSM3491485
# col_name : GSM3491486
# matched_key: GSM3491486
# col_name : GSM3491487
# matched_key: GSM3491487
# col_name : GSM3491488
# matched_key: GSM3491488
# col_name : GSM3491489
# matched_key: GSM3491489
# col_name : GSM3491490
# matched_key: GSM3491490
# col_name : GSM3491491
# matched_key: GSM3491491
# col_name : GSM3491492
# matched_key: GSM3491492
# col_name : GSM3491493
# matched_key: GSM3491493
# col_name : GSM3491494
# matched_key: GSM3491494
# col_name : GSM3491495
# matched_key: GSM3491495
# col_name : GSM3491496
# matched_key: GSM3491496
# col_name : GSM3491497
# matched_key: GSM3491497
# col_name : GSM3491498
# matched_key: GSM3491498
# col_name : GSM3491499
# matched_key: GSM3491499
# col_name : GSM3491500
# matched_key: GSM3491500
# col_name : GSM3491501
# matched_key: GSM3491501
# col_name : GSM3491502
# matched_key: GSM3491502
# col_name : GSM3491503
# matched_key: GSM3491503
# col_name : GSM3491504
# matched_key: GSM3491504
# col_name : GSM3491505
# matched_key: GSM3491505
# col_name : GSM3491506
# matched_key: GSM3491506
# col_name : GSM3491507
# matched_key: GSM3491507
# col_name : GSM3491508
# matched_key: GSM3491508
# col_name : GSM3491509
# matched_key: GSM3491509
# col_name : GSM3491510
# matched_key: GSM3491510
# col_name : GSM3491511
# matched_key: GSM3491511
# col_name : GSM3491512
# matched_key: GSM3491512
# col_name : GSM3491513
# matched_key: GSM3491513
# col_name : GSM3491514
# matched_key: GSM3491514
# col_name : GSM3491515
# matched_key: GSM3491515
# col_name : GSM3491516
# matched_key: GSM3491516
# col_name : GSM3491517
# matched_key: GSM3491517
# col_name : GSM3491518
# matched_key: GSM3491518
# col_name : GSM3491519
# matched_key: GSM3491519
# col_name : GSM3491520
# matched_key: GSM3491520
# col_name : GSM3491521
# matched_key: GSM3491521
# col_name : GSM3491522
# matched_key: GSM3491522
# col_name : GSM3491523
# matched_key: GSM3491523
# col_name : GSM3491524
# matched_key: GSM3491524
# col_name : GSM3491525
# matched_key: GSM3491525
# col_name : GSM3491526
# matched_key: GSM3491526
# col_name : GSM3491527
# matched_key: GSM3491527
# col_name : GSM3491528
# matched_key: GSM3491528
# col_name : GSM3491529
# matched_key: GSM3491529
# col_name : GSM3491530
# matched_key: GSM3491530
# col_name : GSM3491531
# matched_key: GSM3491531
# col_name : GSM3491532
# matched_key: GSM3491532
# col_name : GSM3491533
# matched_key: GSM3491533
# col_name : GSM3491534
# matched_key: GSM3491534
# col_name : GSM3491535
# matched_key: GSM3491535
# col_name : GSM3491536
# matched_key: GSM3491536
# col_name : GSM3491537
# matched_key: GSM3491537
# col_name : GSM3491538
# matched_key: GSM3491538
# col_name : GSM3491539
# matched_key: GSM3491539
# col_name : GSM3491540
# matched_key: GSM3491540
# col_name : GSM3491541
# matched_key: GSM3491541
# col_name : GSM3491542
# matched_key: GSM3491542
# col_name : GSM3491543
# matched_key: GSM3491543
# col_name : GSM3491544
# matched_key: GSM3491544
# col_name : GSM3491545
# matched_key: GSM3491545
# col_name : GSM3491546
# matched_key: GSM3491546
# col_name : GSM3491547
# matched_key: GSM3491547
# col_name : GSM3491548
# matched_key: GSM3491548
# col_name : GSM3491549
# matched_key: GSM3491549
# col_name : GSM3491550
# matched_key: GSM3491550
# col_name : GSM3491551
# matched_key: GSM3491551
# col_name : GSM3491552
# matched_key: GSM3491552
# col_name : GSM3491553
# matched_key: GSM3491553
# col_name : GSM3491554
# matched_key: GSM3491554
# col_name : GSM3491555
# matched_key: GSM3491555
# col_name : GSM3491556
# matched_key: GSM3491556
# col_name : GSM3491557
# matched_key: GSM3491557
# col_name : GSM3491558
# matched_key: GSM3491558
# col_name : GSM3491559
# matched_key: GSM3491559
# col_name : GSM3491560
# matched_key: GSM3491560
# col_name : GSM3491561
# matched_key: GSM3491561
# col_name : GSM3491562
# matched_key: GSM3491562
# col_name : GSM3491563
# matched_key: GSM3491563
# col_name : GSM3491564
# matched_key: GSM3491564
# col_name : GSM3491565
# matched_key: GSM3491565
# col_name : GSM3491566
# matched_key: GSM3491566
# col_name : GSM3491567
# matched_key: GSM3491567
# col_name : GSM3491568
# matched_key: GSM3491568
# col_name : GSM3491569
# matched_key: GSM3491569
# col_name : GSM3491570
# matched_key: GSM3491570
# col_name : GSM3491571
# matched_key: GSM3491571
# col_name : GSM3491572
# matched_key: GSM3491572
# col_name : GSM3491573
# matched_key: GSM3491573
# col_name : GSM3491574
# matched_key: GSM3491574
# col_name : GSM3491575
# matched_key: GSM3491575
# col_name : GSM3491576
# matched_key: GSM3491576
# col_name : GSM3491577
# matched_key: GSM3491577
# col_name : GSM3491578
# matched_key: GSM3491578
# col_name : GSM3491579
# matched_key: GSM3491579
# col_name : GSM3491580
# matched_key: GSM3491580
# col_name : GSM3491581
# matched_key: GSM3491581
# col_name : GSM3491582
# matched_key: GSM3491582
# col_name : GSM3491583
# matched_key: GSM3491583
# col_name : GSM3491584
# matched_key: GSM3491584
# col_name : GSM3491585
# matched_key: GSM3491585
# col_name : GSM3491586
# matched_key: GSM3491586
# col_name : GSM3491587
# matched_key: GSM3491587
# col_name : GSM3491588
# matched_key: GSM3491588
# col_name : GSM3491589
# matched_key: GSM3491589
# col_name : GSM3491590
# matched_key: GSM3491590
# col_name : GSM3491591
# matched_key: GSM3491591
# col_name : GSM3491592
# matched_key: GSM3491592
# col_name : GSM3491593
# matched_key: GSM3491593
# col_name : GSM3491594
# matched_key: GSM3491594
# col_name : GSM3491595
# matched_key: GSM3491595
# col_name : GSM3491596
# matched_key: GSM3491596
# col_name : GSM3491597
# matched_key: GSM3491597
# col_name : GSM3491598
# matched_key: GSM3491598
# col_name : GSM3491599
# matched_key: GSM3491599
# col_name : GSM3491600
# matched_key: GSM3491600
# col_name : GSM3491601
# matched_key: GSM3491601
# col_name : GSM3491602
# matched_key: GSM3491602
# col_name : GSM3491603
# matched_key: GSM3491603
# col_name : GSM3491604
# matched_key: GSM3491604
# col_name : GSM3491605
# matched_key: GSM3491605
# col_name : GSM3491606
# matched_key: GSM3491606
# col_name : GSM3491607
# matched_key: GSM3491607
# col_name : GSM3491608
# matched_key: GSM3491608
# col_name : GSM3491609
# matched_key: GSM3491609
# col_name : GSM3491610
# matched_key: GSM3491610
# col_name : GSM3491611
# matched_key: GSM3491611
# col_name : GSM3491612
# matched_key: GSM3491612
# col_name : GSM3491613
# matched_key: GSM3491613
# col_name : GSM3491614
# matched_key: GSM3491614
# col_name : GSM3491615
# matched_key: GSM3491615
# col_name : GSM3491616
# matched_key: GSM3491616
# col_name : GSM3491617
# matched_key: GSM3491617
# col_name : GSM3491618
# matched_key: GSM3491618
# col_name : GSM3491619
# matched_key: GSM3491619
# col_name : GSM3491620
# matched_key: GSM3491620
# col_name : GSM3491621
# matched_key: GSM3491621
# col_name : GSM3491622
# matched_key: GSM3491622
# col_name : GSM3491623
# matched_key: GSM3491623
# col_name : GSM3491624
# matched_key: GSM3491624
# col_name : GSM3491625
# matched_key: GSM3491625
# col_name : GSM3491626
# matched_key: GSM3491626
# col_name : GSM3491627
# matched_key: GSM3491627
# col_name : GSM3491628
# matched_key: GSM3491628
# col_name : GSM3491629
# matched_key: GSM3491629
# col_name : GSM3491630
# matched_key: GSM3491630
# col_name : GSM3491631
# matched_key: GSM3491631
# col_name : GSM3491632
# matched_key: GSM3491632
# col_name : GSM3491633
# matched_key: GSM3491633
# col_name : GSM3491634
# matched_key: GSM3491634
# col_name : GSM3491635
# matched_key: GSM3491635
# col_name : GSM3491636
# matched_key: GSM3491636
# col_name : GSM3491637
# matched_key: GSM3491637
# col_name : GSM3491638
# matched_key: GSM3491638
# col_name : GSM3491639
# matched_key: GSM3491639
# col_name : GSM3491640
# matched_key: GSM3491640
# col_name : GSM3491641
# matched_key: GSM3491641
# col_name : GSM3491642
# matched_key: GSM3491642
# col_name : GSM3491643
# matched_key: GSM3491643
# col_name : GSM3491644
# matched_key: GSM3491644
# col_name : GSM3491645
# matched_key: GSM3491645
# col_name : GSM3491646
# matched_key: GSM3491646
# col_name : GSM3491647
# matched_key: GSM3491647
# col_name : GSM3491648
# matched_key: GSM3491648
# col_name : GSM3491649
# matched_key: GSM3491649
# col_name : GSM3491650
# matched_key: GSM3491650
# col_name : GSM3491651
# matched_key: GSM3491651
# col_name : GSM3491652
# matched_key: GSM3491652
# col_name : GSM3491653
# matched_key: GSM3491653
# col_name : GSM3491654
# matched_key: GSM3491654
# col_name : GSM3491655
# matched_key: GSM3491655
# col_name : GSM3491656
# matched_key: GSM3491656
# col_name : GSM3491657
# matched_key: GSM3491657
# col_name : GSM3491658
# matched_key: GSM3491658
# col_name : GSM3491659
# matched_key: GSM3491659
# col_name : GSM3491660
# matched_key: GSM3491660
# col_name : GSM3491661
# matched_key: GSM3491661
# col_name : GSM3491662
# matched_key: GSM3491662
# col_name : GSM3491663
# matched_key: GSM3491663
# col_name : GSM3491664
# matched_key: GSM3491664
# col_name : GSM3491665
# matched_key: GSM3491665
# col_name : GSM3491666
# matched_key: GSM3491666
# col_name : GSM3491667
# matched_key: GSM3491667
# col_name : GSM3491668
# matched_key: GSM3491668
# col_name : GSM3491669
# matched_key: GSM3491669
# col_name : GSM3491670
# matched_key: GSM3491670
# col_name : GSM3491671
# matched_key: GSM3491671
# col_name : GSM3491672
# matched_key: GSM3491672
# col_name : GSM3491673
# matched_key: GSM3491673
# col_name : GSM3491674
# matched_key: GSM3491674
# col_name : GSM3491675
# matched_key: GSM3491675
# col_name : GSM3491676
# matched_key: GSM3491676
# col_name : GSM3491677
# matched_key: GSM3491677
# col_name : GSM3491678
# matched_key: GSM3491678
# col_name : GSM3491679
# matched_key: GSM3491679
# col_name : GSM3491680
# matched_key: GSM3491680
# col_name : GSM3491681
# matched_key: GSM3491681
# col_name : GSM3491682
# matched_key: GSM3491682
# col_name : GSM3491683
# matched_key: GSM3491683
# col_name : GSM3491684
# matched_key: GSM3491684
# col_name : GSM3491685
# matched_key: GSM3491685
# col_name : GSM3491686
# matched_key: GSM3491686
# col_name : GSM3491687
# matched_key: GSM3491687
# col_name : GSM3491688
# matched_key: GSM3491688
# col_name : GSM3491689
# matched_key: GSM3491689
# col_name : GSM3491690
# matched_key: GSM3491690
# col_name : GSM3491691
# matched_key: GSM3491691
# col_name : GSM3491692
# matched_key: GSM3491692
# col_name : GSM3491693
# matched_key: GSM3491693
# col_name : GSM3491694
# matched_key: GSM3491694
# col_name : GSM3491695
# matched_key: GSM3491695
# col_name : GSM3491696
# matched_key: GSM3491696
# col_name : GSM3491697
# matched_key: GSM3491697
# col_name : GSM3491698
# matched_key: GSM3491698
# col_name : GSM3491699
# matched_key: GSM3491699
# col_name : GSM3491700
# matched_key: GSM3491700
# col_name : GSM3491701
# matched_key: GSM3491701
# col_name : GSM3491702
# matched_key: GSM3491702
# col_name : GSM3491703
# matched_key: GSM3491703
# col_name : GSM3491704
# matched_key: GSM3491704
# col_name : GSM3491705
# matched_key: GSM3491705
# col_name : GSM3491706
# matched_key: GSM3491706
# col_name : GSM3491707
# matched_key: GSM3491707
# col_name : GSM3491708
# matched_key: GSM3491708
# col_name : GSM3491709
# matched_key: GSM3491709
# col_name : GSM3491710
# matched_key: GSM3491710
# col_name : GSM3491711
# matched_key: GSM3491711
# col_name : GSM3491712
# matched_key: GSM3491712
# col_name : GSM3491713
# matched_key: GSM3491713
# col_name : GSM3491714
# matched_key: GSM3491714
# col_name : GSM3491715
# matched_key: GSM3491715
# col_name : GSM3491716
# matched_key: GSM3491716
# col_name : GSM3491717
# matched_key: GSM3491717
# col_name : GSM3491718
# matched_key: GSM3491718
# col_name : GSM3491719
# matched_key: GSM3491719
# col_name : GSM3491720
# matched_key: GSM3491720
# col_name : GSM3491721
# matched_key: GSM3491721
# col_name : GSM3491722
# matched_key: GSM3491722
# col_name : GSM3491723
# matched_key: GSM3491723
# col_name : F6.1001200103
# matched_key: F6.1001200103
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'F6.1001200103'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[182], line 14
#      12 if matched_key is not None:
#      13     print(f"matched_key: {matched_key}")
# ---> 14     metadata_row = metadata_filtered.loc[matched_key]
#      15     for column in metadata_row.index:
#      16         metadata_to_add.at[col_name, column] = metadata_row[column]
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/generic.py:4095, in NDFrame.xs(self, key, axis, level, drop_level)
#    4093             new_index = index[loc]
#    4094 else:
# -> 4095     loc = index.get_loc(key)
#    4097     if isinstance(loc, np.ndarray):
#    4098         if loc.dtype == np.bool_:
#
# File ~/myenv/lib64/python3.9/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'F6.1001200103'

# %%
# Create AnnData object
adata = sc.AnnData(combined_data.T.values)  # Transpose to match AnnData cell-by-gene format

# Set obs_names (sample IDs) and var_names (gene IDs)
adata.obs_names = combined_data.columns
adata.var_names = combined_data.index

# Combine metadata with obs
adata.obs = pd.concat([adata.obs, metadata_to_add], axis=1)

# %%
combined_data.columns
# Out:
# Index(['GSM3491382', 'GSM3491383', 'GSM3491384', 'GSM3491385', 'GSM3491386',
#        'GSM3491387', 'GSM3491388', 'GSM3491389', 'GSM3491390', 'GSM3491391',
#        ...
#        'GSM3493294', 'GSM3493295', 'GSM3493296', 'GSM3493297', 'GSM3493298',
#        'GSM3493299', 'GSM3493300', 'GSM3493301', 'GSM3493302', 'GSM3493303'],
#       dtype='object', length=1922)

# %%
combined_data.index
# Out:
# Index(['0610005C13Rik', '0610007C21Rik', '0610007L01Rik', '0610007N19Rik',
#        '0610007P08Rik', '0610007P14Rik', '0610007P22Rik', '0610008F07Rik',
#        '0610009B14Rik', '0610009B22Rik',
#        ...
#        'Zxda', 'Zxdb', 'Zxdc', 'Zyg11a', 'Zyg11b', 'Zyx', 'Zzef1', 'Zzz3', 'a',
#        'l7Rn6'],
#       dtype='object', length=23429)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1922 × 23429
#     obs: 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject', 'BioSample', 'Bytes', 'Center Name', 'Consent', 'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region', 'Experiment', 'GEO_Accession (exp)', 'Instrument', 'LibraryLayout', 'LibrarySelection', 'LibrarySource', 'Organism', 'Platform', 'ReleaseDate', 'SRA Study', 'create_date', 'version', 'AGE', 'detected_genes', 'gate', 'genotype', 'plate_id', 'pooled_library_names', 'qc_all_3_criteria', 'qc_detected_genes', 'qc_ercc_correlation', 'qc_total_counts', 'source_name', 'strain', 'tissue', 'total_counts', 'well_id', 'Name'

# %%
adata.obs
# Out:
#            Assay Type  AvgSpotLen        Bases   BioProject     BioSample  \
# GSM3491382    RNA-Seq       150.0  168482850.0  PRJNA507279  SAMN10488168
# GSM3491383    RNA-Seq       150.0  245394750.0  PRJNA507279  SAMN10488167
# GSM3491384    RNA-Seq       150.0  214195950.0  PRJNA507279  SAMN10488166
# GSM3491385    RNA-Seq       150.0  226942050.0  PRJNA507279  SAMN10488165
# GSM3491386    RNA-Seq       150.0  229187700.0  PRJNA507279  SAMN10488164
# ...               ...         ...          ...          ...           ...
# GSM3493299        NaN         NaN          NaN          NaN           NaN
# GSM3493300        NaN         NaN          NaN          NaN           NaN
# GSM3493301        NaN         NaN          NaN          NaN           NaN
# GSM3493302        NaN         NaN          NaN          NaN           NaN
# GSM3493303        NaN         NaN          NaN          NaN           NaN
#
#                  Bytes Center Name Consent DATASTORE filetype  \
# GSM3491382  60931001.0         GEO  public   fastq,run.zq,sra
# GSM3491383  89790040.0         GEO  public   fastq,run.zq,sra
# GSM3491384  78644825.0         GEO  public   fastq,run.zq,sra
# GSM3491385  82714715.0         GEO  public   fastq,run.zq,sra
# GSM3491386  82956576.0         GEO  public   fastq,run.zq,sra
# ...                ...         ...     ...                ...
# GSM3493299         NaN         NaN     NaN                NaN
# GSM3493300         NaN         NaN     NaN                NaN
# GSM3493301         NaN         NaN     NaN                NaN
# GSM3493302         NaN         NaN     NaN                NaN
# GSM3493303         NaN         NaN     NaN                NaN
#
#            DATASTORE provider  ... qc_all_3_criteria qc_detected_genes  \
# GSM3491382         gs,ncbi,s3  ...                 Y                 Y
# GSM3491383         gs,ncbi,s3  ...                 Y                 Y
# GSM3491384         gs,ncbi,s3  ...                 Y                 Y
# GSM3491385         gs,ncbi,s3  ...                 Y                 Y
# GSM3491386         gs,ncbi,s3  ...                 Y                 Y
# ...                       ...  ...               ...               ...
# GSM3493299                NaN  ...               NaN               NaN
# GSM3493300                NaN  ...               NaN               NaN
# GSM3493301                NaN  ...               NaN               NaN
# GSM3493302                NaN  ...               NaN               NaN
# GSM3493303                NaN  ...               NaN               NaN
#
#            qc_ercc_correlation qc_total_counts         source_name   strain  \
# GSM3491382                   Y               Y  Brain myeloid cell  C57BL6N
# GSM3491383                   Y               Y  Brain myeloid cell  C57BL6N
# GSM3491384                   Y               Y  Brain myeloid cell  C57BL6N
# GSM3491385                   Y               Y  Brain myeloid cell  C57BL6N
# GSM3491386                   Y               Y  Brain myeloid cell  C57BL6N
# ...                        ...             ...                 ...      ...
# GSM3493299                 NaN             NaN                 NaN      NaN
# GSM3493300                 NaN             NaN                 NaN      NaN
# GSM3493301                 NaN             NaN                 NaN      NaN
# GSM3493302                 NaN             NaN                 NaN      NaN
# GSM3493303                 NaN             NaN                 NaN      NaN
#
#            tissue total_counts well_id              Name
# GSM3491382    HIP     484029.0      C9   C9.1001200107.0
# GSM3491383     OB     810207.0     B10  B10.1001200106.0
# GSM3491384     OB     714754.0      A8   A8.1001200106.0
# GSM3491385    HIP     716677.0      D6   D6.1001200107.0
# GSM3491386     OB     683013.0     B12  B12.1001200106.0
# ...           ...          ...     ...               ...
# GSM3493299    NaN          NaN     NaN               NaN
# GSM3493300    NaN          NaN     NaN               NaN
# GSM3493301    NaN          NaN     NaN               NaN
# GSM3493302    NaN          NaN     NaN               NaN
# GSM3493303    NaN          NaN     NaN               NaN
#
# [1922 rows x 39 columns]

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [0610005C13Rik, 0610007C21Rik, 0610007L01Rik, 0610007N19Rik, 0610007P08Rik, 0610007P14Rik, 0610007P22Rik, 0610008F07Rik, 0610009B14Rik, 0610009B22Rik, 0610009D07Rik, 0610009L18Rik, 0610009O20Rik, 0610010B08Rik, 0610010F05Rik, 0610010K14Rik, 0610010O12Rik, 0610011F06Rik, 0610011L14Rik, 0610012G03Rik, 0610012H03Rik, 0610030E20Rik, 0610031J06Rik, 0610031O16Rik, 0610037L13Rik, 0610037P05Rik, 0610038B21Rik, 0610038L08Rik, 0610039K10Rik, 0610040B10Rik, 0610040F04Rik, 0610040J01Rik, 0610043K17Rik, 0910001L09Rik, 100043387, 1100001G20Rik, 1110001A16Rik, 1110001J03Rik, 1110002B05Rik, 1110002L01Rik, 1110002N22Rik, 1110003E01Rik, 1110004E09Rik, 1110004F10Rik, 1110005A03Rik, 1110006O24Rik, 1110007C09Rik, 1110008F13Rik, 1110008J03Rik, 1110008L16Rik, 1110008P14Rik, 1110012J17Rik, 1110012L19Rik, 1110014N23Rik, 1110015O18Rik, 1110017D15Rik, 1110017F19Rik, 1110018G07Rik, 1110018J18Rik, 1110019D14Rik, 1110020A21Rik, 1110020G09Rik, 1110021J02Rik, 1110021L09Rik, 1110028C15Rik, 1110028F11Rik, 1110028F18Rik, 1110031I02Rik, 1110032A03Rik, 1110032A04Rik, 1110032F04Rik, 1110034A24Rik, 1110034B05Rik, 1110034G24Rik, 1110035M17Rik, 1110036E04Rik, 1110037F02Rik, 1110038B12Rik, 1110038D17Rik, 1110038F14Rik, 1110046J04Rik, 1110049F12Rik, 1110050K14Rik, 1110051M20Rik, 1110054M08Rik, 1110054O05Rik, 1110057K04Rik, 1110058L19Rik, 1110059E24Rik, 1110059G10Rik, 1110059M19Rik, 1110065P20Rik, 1110067D22Rik, 1190002F15Rik, 1190002H23Rik, 1190002N15Rik, 1190003J15Rik, 1190003K10Rik, 1190005F20Rik, 1190005I06Rik, ...]
#
# [23429 rows x 0 columns]

# %%
# Save the AnnData object
adata.write("GSE123025" +"_GSM_preprocessed_with_metadata.h5ad")

print("Preprocessing complete. AnnData saved with metadata.")
# Out:
# Preprocessing complete. AnnData saved with metadata.
